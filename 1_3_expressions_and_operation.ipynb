# %% [markdown]
# # Expressions and Functions
#
# ## Objectives
#
# 1. Introduce basic Python expressions for transforming data
#     1. Arithmetic
#     2. Boolean
# 2. Use the conditional expression for situational expressions

# %% [markdown]
# ## Expressions and Statements
#
# * Two types of Python code
# * **statements** "Do this"
#     * Does not return/evaluate to a value
#     * Often contain expressions
# * **expressions** "Compute this value"
#     * Allows returns data
# * I prefer expressions

# %%
sum([1,2,3]) # expression (returns 6)
# Out:
# 6

# %%
x = sum([1,2,3]) # assignment statement (no value)

# %%
x # Expression (returns value assigned to x)
# Out:
# 6

# %% [markdown]
# ## Arithmetic operations

# %%
2 + 3.5
# Out:
# 5.5

# %%
2 - 3.5
# Out:
# -1.5

# %%
2*3.5
# Out:
# 7.0

# %%
2/3 # True division
# Out:
# 0.6666666666666666

# %%
10//3 # Integeer division
# Out:
# 3

# %%
10 % 3 # Mod/remainder
# Out:
# 1

# %% [markdown]
# <font color="red"><h2>Exercise</h2></font>
#
# The hour hand is pointing at 8, what will it point to in 57 hours?

# %%
57%12
# Out:
# 9

# %%
8+9
# Out:
# 17

# %%
17-12
# Out:
# 5

# %%
(8+57)%24
# Out:
# 17

# %%
17-12
# Out:
# 5

# %%
2 ** 3 # Powers!
# Out:
# 8

# %%
2 ^ 3 # BEWARE: bitwise exclusive or
# Out:
# 1

# %% [markdown]
# ### <font color="red"> Exercise 1</font>
# Investigate which operations can be applied to two strings, say `"a"` and `"b"`.

# %%
"a"*"b"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-4a2907541deb> in <module>()
# ----> 1 "a"*"b"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
"a"^"b"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-0a27f74c457c> in <module>()
# ----> 1 "a"^"b"
#
# TypeError: unsupported operand type(s) for ^: 'str' and 'str'

# %%
"a"// "b"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-9f0974fa5f13> in <module>()
# ----> 1 "a"// "b"
#
# TypeError: unsupported operand type(s) for //: 'str' and 'str'

# %%
"a"+"b"
# Out:
# 'ab'

# %%
"a"%"b"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-edab2957cf77> in <module>()
# ----> 1 "a"%"b"
#
# TypeError: not all arguments converted during string formatting

# %%
"A"-"b"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-0de08ee5f06e> in <module>()
# ----> 1 "A"-"b"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
"a"=="b"
# Out:
# False

# %%
"a"**"b"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-87c5d034004d> in <module>()
# ----> 1 "a"**"b"
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'str'

# %% [markdown]
# ### <font color="red"> Exercise 2 </font>
#
# Investigate various operations on `2` and `"a"`

# %%
2*"a"
# Out:
# 'aa'

# %%
2/"a"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-2d93b7b9b82b> in <module>()
# ----> 1 2/"a"
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
2+"a"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-19c4be273b8f> in <module>()
# ----> 1 2+"a"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
2-"a"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-e8efef910f58> in <module>()
# ----> 1 2-"a"
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
"a"%2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-e9b26e3c4cf6> in <module>()
# ----> 1 "a"%2
#
# TypeError: not all arguments converted during string formatting

# %%
2//"a"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-57b4f4398e18> in <module>()
# ----> 1 2//"a"
#
# TypeError: unsupported operand type(s) for //: 'int' and 'str'

# %%
2 + 3.0
# Out:
# 5.0

# %% [markdown]
# ## Boolean operations
#
# - **Boolean expressions** evaluate to True or False
# - **Boolean operations** answer Yes/No questions

# %% [markdown]
# ## Comparison operators

# %%
(2 == 3,
 2 < 3,
 2 <= 3,
 2 != 3)
# Out:
# (False, True, True, True)

# %% [markdown]
# ## Container operations

# %%
2 in [1,2,3]
# Out:
# True

# %%
"a" in "Todd"
# Out:
# False

# %%
"t" not in "Todd"
# Out:
# True

# %%
2 in [1, [2, 3]]
# Out:
# False

# %% [markdown]
# ### <font color="red"> Exercise 3</font>
#
# Why does `2 in [1, [2, 3]]` to `False`?

# %%
2 in [1,2]
# Out:
# True

# %%
2in [1,3]
# Out:
# False

# %%
2 in [2,[2,3]]
# Out:
# True

# %%
2 in [1,[2,3]]
# Out:
# False

# %% [markdown]
# ## Combining boolean expressions
#
# - Use `and`, `or`, and `not`

# %%
x, name = 5, "Todd"
x % 2 == 1 and "a" in "Todd"
# Out:
# False

# %%
x % 2 == 1 or "a" in "Todd"
# Out:
# True

# %%
not 2 < 3
# Out:
# False

# %% [markdown]
# ## Conditional Expression
#
# * Syntax:

# %%
true_val if boolean_condition else false_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-3ae810e1a1d8> in <module>()
# ----> 1 true_val if boolean_condition else false_value
#
# NameError: name 'boolean_condition' is not defined

# %%
"Has t" if "t" in "Todd" else "No t"
# Out:
# 'No t'

# %% [markdown]
# ## Evaluating the conditional expression
#
# <img src="https://github.com/SamBroberg/module1_lectures/blob/master/img/cond_expr_1.png?raw=1" width=400 />

# %% [markdown]
# ### <font color="red"> Exercise 4</font>
#
# Evaluate `"Yes" if (5 <= x < 10) and (x % 2 == 1) else "No"`
#
# 1. By hand
# 2. With Python

# %%
x
# Out:
# 5

# %%
(5<= x < 10)
# Out:
# True

# %%
(x % 2 == 1)
# Out:
# True

# %%
"Yes" if (5<= x <10) and (x % 2 == 1) else "No"
# Out:
# 'Yes'

# %%
"Yes" if (5<= 5 <10) and (5 % 2 == 1) else "No"
# Out:
# 'Yes'

# %% [markdown]
# 1. Evaluate by hand:

# %%
# Evaluate with Python
x = 6.1
"Yes" if (5 <= x < 10) and (x % 2 == 1) else "No"
# Out:
# 'No'

# %%
x % 2
# Out:
# 0.09999999999999964

# %%
"Yes" if (5<= 6.1 <10) and (6.1 % 2 == 1) else "No"
# Out:
# 'No'
